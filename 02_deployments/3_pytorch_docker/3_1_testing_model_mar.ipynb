# %%
# !torchserve --start \
  --model-store . \
  --models model=model_mar.mar \
  --ncs \
  --disable-token-auth

# %%
# gs://my-model-training/pipeline_root/kfp/344969539300/pipeline-20260827124514/package-model_-8304349280047464448/model_mar.mar

# %%
# !gsutil cp gs://my-model-training/pipeline_root/kfp/344969539300/pipeline-20260827124514/package-model_-8304349280047464448/model_mar.mar ./model_mar.mar
# Out:
# Google recommends using Gcloud storage CLI (https://docs.cloud.google.com/storage/docs/discover-object-storage-gcloud) instead of gsutil. Please refer to migration guide (https://docs.cloud.google.com/storage/docs/gsutil-transition-to-gcloud) for assistance.
# Copying gs://my-model-training/pipeline_root/kfp/344969539300/pipeline-20260827124514/package-model_-8304349280047464448/model_mar.mar...
# / [1 files][  2.9 KiB/  2.9 KiB]
# Operation completed over 1 objects/2.9 KiB.

# %%
# !torchserve --stop
# Out:
# TorchServe has stopped.

# %%
# !curl http://localhost:8081/models
# Out:
# {
#   "models": [
#     {
#       "modelName": "model",
#       "modelUrl": "model_mar.mar"
#     }
#   ]
# }

# %%
# !curl -X POST http://localhost:8080/predictions/model \
  -H "Content-Type: application/json" \
  -d '{"data": [[1.0, 2.0, 3.0, 4.0],[1.0, 2.0, 3.0, 9.0]]}'
# Out:
# [
#   [
#     2.4727349281311035
#   ],
#   [
#     4.8921403884887695
#   ]
# ]
