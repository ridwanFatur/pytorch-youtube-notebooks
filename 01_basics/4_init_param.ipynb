# %%
from torch import tensor, nn
import torch

# %% [markdown]
# ### Seed

# %%
torch.manual_seed(42)

# %%
model = nn.Linear(1,1)

# %%
# New
model.weight, model.bias
# Out:
# (Parameter containing:
#  tensor([[0.7645]], requires_grad=True),
#  Parameter containing:
#  tensor([0.8300], requires_grad=True))

# %%
# Old
model.weight, model.bias
# Out:
# (Parameter containing:
#  tensor([[0.7645]], requires_grad=True),
#  Parameter containing:
#  tensor([0.8300], requires_grad=True))

# %% [markdown]
# ### Hardcoded

# %%
model = nn.Linear(1,1)
model.load_state_dict({
    "weight": torch.tensor([[0.7645]]),
    "bias": torch.tensor([0.8300])
})
# Out:
# <All keys matched successfully>

# %%
model.weight, model.bias
# Out:
# (Parameter containing:
#  tensor([[0.7645]], requires_grad=True),
#  Parameter containing:
#  tensor([0.8300], requires_grad=True))

# %% [markdown]
# ### Save & Load

# %%
model.state_dict()
# Out:
# OrderedDict([('weight', tensor([[0.7645]])), ('bias', tensor([0.8300]))])

# %%
torch.save(model.state_dict(), "model.pth")

# %%
state_dict = torch.load("model.pth")

# %%
state_dict
# Out:
# OrderedDict([('weight', tensor([[0.7645]])), ('bias', tensor([0.8300]))])

# %%
new_model = nn.Linear(1,1)
new_model.load_state_dict(state_dict)
# Out:
# <All keys matched successfully>

# %%
new_model = nn.Linear(2,1)
new_model.load_state_dict(state_dict)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[12], line 2
#       1 new_model = nn.Linear(2,1)
# ----> 2 new_model.load_state_dict(state_dict)
#
# File ~/miniconda3/envs/py3_12_9/lib/python3.12/site-packages/torch/nn/modules/module.py:2638, in Module.load_state_dict(self, state_dict, strict, assign)
#    2630         error_msgs.insert(
#    2631             0,
#    2632             "Missing key(s) in state_dict: {}. ".format(
#    2633                 ", ".join(f'"{k}"' for k in missing_keys)
#    2634             ),
#    2635         )
#    2637 if len(error_msgs) > 0:
# -> 2638     raise RuntimeError(
#    2639         "Error(s) in loading state_dict for {}:\n\t{}".format(
#    2640             self.__class__.__name__, "\n\t".join(error_msgs)
#    2641         )
#    2642     )
#    2643 return _IncompatibleKeys(missing_keys, unexpected_keys)
#
# ...

# %% [markdown]
# ### Other Configs

# %%
model = nn.Linear(1,1, bias=False)

# %%
model.weight, model.bias
# Out:
# (Parameter containing:
#  tensor([[-0.7336]], requires_grad=True),
#  None)

# %%
model = nn.Linear(10000,1, bias=False)

# %%
model.weight[:10]
# Out:
# tensor([[-0.0003,  0.0078,  0.0096,  ...,  0.0096,  0.0056, -0.0091]],
#        grad_fn=<SliceBackward0>)

# %%
model.weight.mean(), model.weight.std()
# Out:
# (tensor(0.0123, grad_fn=<MeanBackward0>),
#  tensor(0.9914, grad_fn=<StdBackward0>))

# %%
nn.init.normal_(model.weight, mean=0.0, std=4)
pass

# %%
model.weight.mean(), model.weight.std()
# Out:
# (tensor(-0.0354, grad_fn=<MeanBackward0>),
#  tensor(3.9884, grad_fn=<StdBackward0>))
